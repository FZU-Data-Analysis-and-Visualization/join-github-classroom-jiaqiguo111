# %%
1+3
# Out:
# 4

# %% [markdown]
# ---

# %%
import numpy as bq

# %%
conda activate eda
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# If using 'conda activate' from a batch script, change your
# invocation to 'CALL conda.bat activate'.
#
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - cmd.exe
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
conda install pandas
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\31679\.conda\envs\eda
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-3.0.2               |  py312hf6ff4c0_0        13.0 MB
#     python-tzdata-2026.2       |     pyhd3eb1b0_0         140 KB
#     ------------------------------------------------------------
#                                            Total:        13.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             pkgs/main/win-64::pandas-3.0.2-py312hf6ff4c0_0 None
#   python-tzdata      pkgs/main/noarch::python-tzdata-2026.2-pyhd3eb1b0_0 None
#
#
#
# ...
#
# python-tzdata-2026.2 | 140 KB    |            |   0%
# python-tzdata-2026.2 | 140 KB    | #1         |  11%
# python-tzdata-2026.2 | 140 KB    | ####5      |  46%
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.2
